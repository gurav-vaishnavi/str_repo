# %%
# string
    #String is an immutable, ordered sequence of chracters. String can be represented in the  quotation mark. 

#1 capitalize
str="hello"
str.capitalize()
# Out:
# 'Hello'

# %%
#2 upper and lower
str='demo'
print(str.upper())
print(str.lower())
# Out:
# DEMO
# demo

# %%
#3 title
str='phy math'
str.title()
# Out:
# 'Phy Math'

# %%
#4 swapcase
str='hII'
str.swapcase()
# Out:
# 'Hii'

# %%
#5 lstrip, rstrip, strip
text="   hello python----"
print(text.lstrip())
print(text.rstrip('-'))
print(text.strip())
# Out:
# hello python----
#    hello python
# hello python----

# %%
#6replace
str=text.replace('python','world')
print(str)
# Out:
#    hello world----

# %%
#7 count
text.count('-')
# Out:
# 4

# %%
#8 index
text.index('l')
# Out:
# 5

# %%
#9find()
text.find('e',1)
# Out:
# 4

# %%
#10 split()
text.split(" ")
# Out:
# ['', '', '', 'hello', 'python----']

# %%
#11 join
str='hii'
s='hello' 
str.join(s)
# Out:
# 'hhiiehiilhiilhiio'

# %%
#12startswith() and endswith()
print(text.startswith('hello'))

print(text.endswith('-'))
# Out:
# False
# True

# %%
#13  isalnum()
str='ab12'
str.isalnum()
# Out:
# True

# %%
# 14 isalpha()
str.isalpha()
# Out:
# False

# %%
#15 isdecimal()
s='123.67'
s.isdecimal()
s1='23'
s1.isdecimal()
# Out:
# True

# %%
s='2 3'
s.isdigit()
s1='23'
s1.isdigit()
# Out:
# True

# %%
#17 isnumeric()
S='2/2.7'
print(S.isnumeric())
s1='234'
print(s1.isnumeric())
# Out:
# False
# True

# %%
#18 isupper and islower
string='Hello python'
print(string.isupper())
print(string.islower())
# Out:
# False
# False

# %%
#19istitle
text='Good Morning'
text.istitle()
# Out:
# True

# %%
#zfill()
text="42"
text.zfill(5)
# Out:
# '00042'

# %%
#center()
text=" hello"
text.center()
# Out:
# '   hello  '

# %%
text="python2"
text.center(20,'-')
# Out:
# '------python2-------'

# %%
def print_full_name(first,last):
    if len(str(first))<10 and len(str(last))<10:
        x=f'{first}{last} is student'
        return x

print_full_name('A','B')
# Out:
# 'AB is student'
